# %%
import os
from dwave.system import LeapHybridSampler

# Set the D-Wave API token
os.environ['DWAVE_API_TOKEN'] = 'DEV-86d6148189fcef5234fca13225bfc72fb5533447'

# Define the Ising model parameters
J = {(0, 1): -1.0, (1, 2): -1.0}  # Coupler strengths
h = {0: 0.5, 1: 0.5, 2: 0.5}       # Qubit biases

# Create a sampler instance
sampler = LeapHybridSampler()

# Solve the Ising model on the D-Wave quantum annealer
response = sampler.sample_ising(h, J)

# Retrieve the optimal solution
optimal_solution = next(response.samples())

print("Optimal solution:", optimal_solution)
# Out:
# ---------------------------------------------------------------------------
# SolverFailureError                        Traceback (most recent call last)
# Cell In[2], line 18
#      15 response = sampler.sample_ising(h, J)
#      17 # Retrieve the optimal solution
# ---> 18 optimal_solution = next(response.samples())
#      20 print("Optimal solution:", optimal_solution)
#
# File ~/anaconda3/envs/isingmodel/lib/python3.10/site-packages/dimod/sampleset.py:1215, in SampleSet.samples(self, n, sorted_by)
#    1213     samples = self.record.sample
#    1214 else:
# -> 1215     order = np.argsort(self.record[sorted_by])
#    1216     samples = self.record.sample[order]
#    1218 return SamplesArray(samples, self.variables)
#
# File ~/anaconda3/envs/isingmodel/lib/python3.10/site-packages/dimod/sampleset.py:1121, in SampleSet.record(self)
#    1105 @property
#    1106 def record(self):
#    1107     """:obj:`numpy.recarray` containing the samples, energies, number of occurences, and other sample data.
#    1108
#    1109     Examples:
#    (...)
#    1119
#    1120     """
# -> 1121     self.resolve()
#    1122     return self._record
#
# File ~/anaconda3/envs/isingmodel/lib/python3.10/site-packages/dimod/sampleset.py:1485, in SampleSet.resolve(self)
#    1483 # if it doesn't have the attribute then it is already resolved
#    1484 if hasattr(self, '_future'):
# -> 1485     samples = self._result_hook(self._future)
#    1486     self.__init__(samples.record, samples.variables, samples.info, samples.vartype)
#    1487     del self._future
#
# File ~/anaconda3/envs/isingmodel/lib/python3.10/site-packages/dwave/cloud/computation.py:823, in Future.sampleset.<locals>.<lambda>(f)
#     818 except ImportError:
#     819     raise RuntimeError("Can't construct SampleSet without dimod. "
#     820                        "Re-install the library with 'bqm' support.")
#     822 self._sampleset = sampleset = dimod.SampleSet.from_future(
# --> 823     self, lambda f: f.wait_sampleset())
#     825 # propagate id to sampleset as well
#     826 # note: this requires dimod>=0.8.21 (before that version SampleSet
#     827 # had slots set which prevented dynamic addition of attributes).
#     828 sampleset.wait_id = self.wait_id
#
# File ~/anaconda3/envs/isingmodel/lib/python3.10/site-packages/dwave/cloud/computation.py:755, in Future.wait_sampleset(self)
#     752 """Blocking sampleset getter."""
#     754 # blocking result get
# --> 755 result = self._load_result()
#     757 # common problem info: id/label
#     758 problem_info = dict(problem_id=self.id)
#
# File ~/anaconda3/envs/isingmodel/lib/python3.10/site-packages/dwave/cloud/computation.py:893, in Future._load_result(self)
#     891 # Check for other error conditions
#     892 if self._exception is not None:
# --> 893     raise self._exception
#     895 # If someone else took care of this while we were waiting
#     896 if self._result is not None:
#
# File ~/anaconda3/envs/isingmodel/lib/python3.10/site-packages/dwave/cloud/client/base.py:1309, in Client._handle_problem_status(self, message, future)
#    1307 if 'error_code' in message and 'error_msg' in message:
#    1308     logger.debug("Error response received: %r", message)
# -> 1309     raise SolverFailureError(message['error_msg'])
#    1311 if 'status' not in message:
#    1312     raise InvalidAPIResponseError("'status' missing in problem description response")
#
# SolverFailureError: Problem not accepted because user has insufficient remaining solver access time in project DEV.

# %%
pip install dwave-ocean-sdk
# Out:
# Collecting dwave-ocean-sdk
#   Downloading dwave_ocean_sdk-6.8.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting dimod==0.12.14 (from dwave-ocean-sdk)
#   Downloading dimod-0.12.14-cp310-cp310-macosx_11_0_arm64.whl.metadata (4.0 kB)
# Collecting dwave-cloud-client==0.11.2 (from dwave-ocean-sdk)
#   Downloading dwave_cloud_client-0.11.2-py3-none-any.whl.metadata (5.3 kB)
# Collecting dwave-greedy==0.3.0 (from dwave-ocean-sdk)
#   Downloading dwave_greedy-0.3.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting dwave-hybrid==0.6.10 (from dwave-ocean-sdk)
#   Downloading dwave_hybrid-0.6.10-py3-none-any.whl.metadata (4.6 kB)
# Collecting dwave-inspector==0.4.4 (from dwave-ocean-sdk)
#   Downloading dwave_inspector-0.4.4-py3-none-any.whl.metadata (4.4 kB)
# Collecting dwave-neal==0.6.0 (from dwave-ocean-sdk)
#   Downloading dwave_neal-0.6.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting dwave-networkx==0.8.14 (from dwave-ocean-sdk)
#   Downloading dwave_networkx-0.8.14-py3-none-any.whl.metadata (2.6 kB)
# Collecting dwave-preprocessing==0.6.5 (from dwave-ocean-sdk)
#   Downloading dwave_preprocessing-0.6.5-cp310-cp310-macosx_11_0_arm64.whl.metadata (3.3 kB)
# Collecting dwave-samplers==1.2.0 (from dwave-ocean-sdk)
#   Downloading dwave_samplers-1.2.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.8 kB)
# Collecting dwave-system==1.23.0 (from dwave-ocean-sdk)
#   Downloading dwave_system-1.23.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dwave-tabu==0.5.0 (from dwave-ocean-sdk)
#   Downloading dwave_tabu-0.5.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting dwavebinarycsp==0.3.0 (from dwave-ocean-sdk)
#   Downloading dwavebinarycsp-0.3.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting minorminer==0.2.13 (from dwave-ocean-sdk)
#   Downloading minorminer-0.2.13-cp310-cp310-macosx_11_0_arm64.whl.metadata (1.4 kB)
# Collecting penaltymodel==1.1.0 (from dwave-ocean-sdk)
#   Downloading penaltymodel-1.1.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting numpy<2.0.0,>=1.17.3 (from dimod==0.12.14->dwave-ocean-sdk)
#   Downloading numpy-1.26.4-cp310-cp310-macosx_11_0_arm64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.18 in /Users/furkanpolat/anaconda3/envs/isingmodel/lib/python3.10/site-packages (from requests[socks]>=2.18->dwave-cloud-client==0.11.2->dwave-ocean-sdk) (2.31.0)
# Collecting pydantic<3,>=2 (from dwave-cloud-client==0.11.2->dwave-ocean-sdk)
#   Downloading pydantic-2.6.1-py3-none-any.whl.metadata (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.5/83.5 kB 5.5 MB/s eta 0:00:00
# Collecting homebase>=1.0 (from dwave-cloud-client==0.11.2->dwave-ocean-sdk)
#   Downloading homebase-1.0.1-py2.py3-none-any.whl (11 kB)
# Collecting click>=7.0 (from dwave-cloud-client==0.11.2->dwave-ocean-sdk)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/furkanpolat/anaconda3/envs/isingmodel/lib/python3.10/site-packages (from dwave-cloud-client==0.11.2->dwave-ocean-sdk) (2.8.2)
# Collecting plucky>=0.4.3 (from dwave-cloud-client==0.11.2->dwave-ocean-sdk)
#   Downloading plucky-0.4.3-py2.py3-none-any.whl (10 kB)
# Collecting diskcache>=5.2.1 (from dwave-cloud-client==0.11.2->dwave-ocean-sdk)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: packaging>=19 in /Users/furkanpolat/anaconda3/envs/isingmodel/lib/python3.10/site-packages (from dwave-cloud-client==0.11.2->dwave-ocean-sdk) (23.1)
# Collecting werkzeug>=2.2 (from dwave-cloud-client==0.11.2->dwave-ocean-sdk)
#   Downloading werkzeug-3.0.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/furkanpolat/anaconda3/envs/isingmodel/lib/python3.10/site-packages (from dwave-cloud-client==0.11.2->dwave-ocean-sdk) (4.9.0)
# Collecting authlib<2,>=1.2 (from dwave-cloud-client==0.11.2->dwave-ocean-sdk)
#   Downloading Authlib-1.3.0-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting importlib-metadata>=5.0.0 (from dwave-cloud-client==0.11.2->dwave-ocean-sdk)
#   Downloading importlib_metadata-7.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting networkx (from dwave-hybrid==0.6.10->dwave-ocean-sdk)
#   Downloading networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting Flask>=2.2 (from dwave-inspector==0.4.4->dwave-ocean-sdk)
#   Downloading flask-3.0.2-py3-none-any.whl.metadata (3.6 kB)
# Collecting scipy>=1.7.3 (from dwave-system==1.23.0->dwave-ocean-sdk)
#   Downloading scipy-1.12.0-cp310-cp310-macosx_12_0_arm64.whl.metadata (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.9/112.9 kB 6.6 MB/s eta 0:00:00
# Collecting fasteners>=0.15 (from minorminer==0.2.13->dwave-ocean-sdk)
#   Downloading fasteners-0.19-py3-none-any.whl.metadata (4.9 kB)
# Collecting rectangle-packer>=2.0.1 (from minorminer==0.2.13->dwave-ocean-sdk)
#   Downloading rectangle-packer-2.0.2.tar.gz (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.6/99.6 kB 6.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting cryptography (from authlib<2,>=1.2->dwave-cloud-client==0.11.2->dwave-ocean-sdk)
#   Downloading cryptography-42.0.4-cp39-abi3-macosx_10_12_universal2.whl.metadata (5.3 kB)
# Requirement already satisfied: Jinja2>=3.1.2 in /Users/furkanpolat/anaconda3/envs/isingmodel/lib/python3.10/site-packages (from Flask>=2.2->dwave-inspector==0.4.4->dwave-ocean-sdk) (3.1.3)
# Collecting itsdangerous>=2.1.2 (from Flask>=2.2->dwave-inspector==0.4.4->dwave-ocean-sdk)
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting blinker>=1.6.2 (from Flask>=2.2->dwave-inspector==0.4.4->dwave-ocean-sdk)
#   Downloading blinker-1.7.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting zipp>=0.5 (from importlib-metadata>=5.0.0->dwave-cloud-client==0.11.2->dwave-ocean-sdk)
#   Downloading zipp-3.17.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting annotated-types>=0.4.0 (from pydantic<3,>=2->dwave-cloud-client==0.11.2->dwave-ocean-sdk)
#   Downloading annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.16.2 (from pydantic<3,>=2->dwave-cloud-client==0.11.2->dwave-ocean-sdk)
#   Downloading pydantic_core-2.16.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.5 kB)
# Requirement already satisfied: six>=1.5 in /Users/furkanpolat/anaconda3/envs/isingmodel/lib/python3.10/site-packages (from python-dateutil>=2.7->dwave-cloud-client==0.11.2->dwave-ocean-sdk) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/furkanpolat/anaconda3/envs/isingmodel/lib/python3.10/site-packages (from requests>=2.18->requests[socks]>=2.18->dwave-cloud-client==0.11.2->dwave-ocean-sdk) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/furkanpolat/anaconda3/envs/isingmodel/lib/python3.10/site-packages (from requests>=2.18->requests[socks]>=2.18->dwave-cloud-client==0.11.2->dwave-ocean-sdk) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/furkanpolat/anaconda3/envs/isingmodel/lib/python3.10/site-packages (from requests>=2.18->requests[socks]>=2.18->dwave-cloud-client==0.11.2->dwave-ocean-sdk) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/furkanpolat/anaconda3/envs/isingmodel/lib/python3.10/site-packages (from requests>=2.18->requests[socks]>=2.18->dwave-cloud-client==0.11.2->dwave-ocean-sdk) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /Users/furkanpolat/anaconda3/envs/isingmodel/lib/python3.10/site-packages (from requests[socks]>=2.18->dwave-cloud-client==0.11.2->dwave-ocean-sdk) (1.7.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/furkanpolat/anaconda3/envs/isingmodel/lib/python3.10/site-packages (from werkzeug>=2.2->dwave-cloud-client==0.11.2->dwave-ocean-sdk) (2.1.3)
# Requirement already satisfied: cffi>=1.12 in /Users/furkanpolat/anaconda3/envs/isingmodel/lib/python3.10/site-packages (from cryptography->authlib<2,>=1.2->dwave-cloud-client==0.11.2->dwave-ocean-sdk) (1.16.0)
# Requirement already satisfied: pycparser in /Users/furkanpolat/anaconda3/envs/isingmodel/lib/python3.10/site-packages (from cffi>=1.12->cryptography->authlib<2,>=1.2->dwave-cloud-client==0.11.2->dwave-ocean-sdk) (2.21)
# Downloading dwave_ocean_sdk-6.8.0-py3-none-any.whl (8.4 kB)
# Downloading dimod-0.12.14-cp310-cp310-macosx_11_0_arm64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 10.0 MB/s eta 0:00:00a 0:00:01
# Downloading dwave_cloud_client-0.11.2-py3-none-any.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.8/138.8 kB 8.3 MB/s eta 0:00:00
# Downloading dwave_greedy-0.3.0-py3-none-any.whl (10 kB)
# Downloading dwave_hybrid-0.6.10-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.8/74.8 kB 7.1 MB/s eta 0:00:00
# Downloading dwave_inspector-0.4.4-py3-none-any.whl (31 kB)
# Downloading dwave_neal-0.6.0-py3-none-any.whl (8.7 kB)
# Downloading dwave_networkx-0.8.14-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.4/102.4 kB 10.3 MB/s eta 0:00:00
# Downloading dwave_preprocessing-0.6.5-cp310-cp310-macosx_11_0_arm64.whl (715 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 715.7/715.7 kB 10.6 MB/s eta 0:00:00a 0:00:01
# Downloading dwave_samplers-1.2.0-cp310-cp310-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 11.3 MB/s eta 0:00:0000:0100:01
# Downloading dwave_system-1.23.0-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 7.1 MB/s eta 0:00:00
# Downloading dwave_tabu-0.5.0-py3-none-any.whl (9.2 kB)
# Downloading dwavebinarycsp-0.3.0-py3-none-any.whl (35 kB)
# Downloading minorminer-0.2.13-cp310-cp310-macosx_11_0_arm64.whl (887 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.9/887.9 kB 10.6 MB/s eta 0:00:0000:0100:01
# Downloading penaltymodel-1.1.0-py3-none-any.whl (36 kB)
# Downloading Authlib-1.3.0-py2.py3-none-any.whl (223 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.7/223.7 kB 9.6 MB/s eta 0:00:00
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 8.7 MB/s eta 0:00:00
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 2.6 MB/s eta 0:00:00
# Downloading fasteners-0.19-py3-none-any.whl (18 kB)
# Downloading flask-3.0.2-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.3/101.3 kB 9.5 MB/s eta 0:00:00
# Downloading importlib_metadata-7.0.1-py3-none-any.whl (23 kB)
# Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 6.3 MB/s eta 0:00:00a 0:00:01
# Downloading numpy-1.26.4-cp310-cp310-macosx_11_0_arm64.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 11.4 MB/s eta 0:00:0000:010:01
# Downloading pydantic-2.6.1-py3-none-any.whl (394 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.8/394.8 kB 8.9 MB/s eta 0:00:00:00:01
# Downloading pydantic_core-2.16.2-cp310-cp310-macosx_11_0_arm64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 11.2 MB/s eta 0:00:00a 0:00:01
# Downloading scipy-1.12.0-cp310-cp310-macosx_12_0_arm64.whl (31.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 9.6 MB/s eta 0:00:0000:01m00:01
# Downloading werkzeug-3.0.1-py3-none-any.whl (226 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 6.5 MB/s eta 0:00:00
# Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Downloading blinker-1.7.0-py3-none-any.whl (13 kB)
# Downloading zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Downloading cryptography-42.0.4-cp39-abi3-macosx_10_12_universal2.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 8.7 MB/s eta 0:00:0000:0100:01m
# Building wheels for collected packages: rectangle-packer
#   Building wheel for rectangle-packer (setup.py) ... done
#   Created wheel for rectangle-packer: filename=rectangle_packer-2.0.2-cp310-cp310-macosx_11_0_arm64.whl size=56310 sha256=9c2b00306132e1915521c11ad60c8f026b50028cf9d2657e502f023d0b831d18
#   Stored in directory: /Users/furkanpolat/Library/Caches/pip/wheels/1c/2e/8e/558a42a62ec5d7af1602c06ee08fe7aca3824c9927c9c19958
# Successfully built rectangle-packer
# Installing collected packages: rectangle-packer, plucky, homebase, zipp, werkzeug, pydantic-core, numpy, networkx, itsdangerous, fasteners, diskcache, click, blinker, annotated-types, scipy, pydantic, importlib-metadata, Flask, dimod, cryptography, penaltymodel, dwave-samplers, dwave-preprocessing, dwave-networkx, authlib, minorminer, dwavebinarycsp, dwave-tabu, dwave-neal, dwave-greedy, dwave-cloud-client, dwave-system, dwave-inspector, dwave-hybrid, dwave-ocean-sdk
# Successfully installed Flask-3.0.2 annotated-types-0.6.0 authlib-1.3.0 blinker-1.7.0 click-8.1.7 cryptography-42.0.4 dimod-0.12.14 diskcache-5.6.3 dwave-cloud-client-0.11.2 dwave-greedy-0.3.0 dwave-hybrid-0.6.10 dwave-inspector-0.4.4 dwave-neal-0.6.0 dwave-networkx-0.8.14 dwave-ocean-sdk-6.8.0 dwave-preprocessing-0.6.5 dwave-samplers-1.2.0 dwave-system-1.23.0 dwave-tabu-0.5.0 dwavebinarycsp-0.3.0 fasteners-0.19 homebase-1.0.1 importlib-metadata-7.0.1 itsdangerous-2.1.2 minorminer-0.2.13 networkx-3.2.1 numpy-1.26.4 penaltymodel-1.1.0 plucky-0.4.3 pydantic-2.6.1 pydantic-core-2.16.2 rectangle-packer-2.0.2 scipy-1.12.0 werkzeug-3.0.1 zipp-3.17.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import matplotlib.pyplot as plt
from dwave.system import LeapHybridSampler

# Set the D-Wave API token
os.environ['DWAVE_API_TOKEN'] = 'DEV-86d6148189fcef5234fca13225bfc72fb5533447'

# Define the Ising model parameters
J = {(0, 1): -1.0, (1, 2): -1.0}  # Coupler strengths
h = {0: 0.5, 1: 0.5, 2: 0.5}       # Qubit biases

# Create a sampler instance
sampler = LeapHybridSampler()

# Solve the Ising model on the D-Wave quantum annealer
response = sampler.sample_ising(h, J)

# Retrieve the optimal solution
optimal_solution = next(response.samples())

# Visualize the Ising model
plt.figure(figsize=(8, 6))
plt.title("Ising Model Circuit")
plt.bar(range(len(h)), h.values(), color='b', label='Qubit biases')
for i, (q1, q2) in enumerate(J.keys()):
    plt.plot([q1, q2], [h[q1], h[q2]], 'r--', label=f'Coupler ({q1}, {q2})')
plt.xlabel("Qubits")
plt.ylabel("Bias/Strength")
plt.xticks(range(len(h)), h.keys())
plt.legend()
plt.grid(True)
plt.show()

# Visualize the samples obtained from the quantum annealer
plt.figure(figsize=(8, 6))
plt.title("Samples from Quantum Annealer")
for sample in response.samples():
    plt.bar(range(len(sample)), sample.values(), alpha=0.5)
plt.xlabel("Qubits")
plt.ylabel("Value")
plt.xticks(range(len(sample)), sample.keys())
plt.grid(True)
plt.show()

print("Optimal solution:", optimal_solution)
# Out:
# /var/folders/2y/vjxw9jx51dl08gjq4h3_3h7r0000gn/T/ipykernel_18650/3624595594.py:19: DeprecationWarning: SampleSet.samples() will return an iterable not an iterator in the future
#   optimal_solution = next(response.samples())
# Optimal solution: {0: -1, 1: -1, 2: -1}

# %%
import os
from dwave.system import LeapHybridSampler

# Set the D-Wave API token
os.environ['DWAVE_API_TOKEN'] = 'DEV-f74a9e03362957010ecbf6a87a746477f7c6a61a'

# Define the Ising model parameters
J = {(0, 1): -1.0, (1, 2): -1.0 , (2, 0): -1.0}  # Coupler strengths
h = {0: 0.5, 1: 0.5, 2: 0.5}      # Qubit biases

# Create a sampler instance
sampler = LeapHybridSampler()

# Solve the Ising model on the D-Wave quantum annealer
response = sampler.sample_ising(h, J)

# Retrieve the optimal solution
optimal_solution = next(response.samples())

print("Optimal solution:", optimal_solution)
# Out:
# Optimal solution: {0: -1, 1: -1, 2: -1}
# /var/folders/2y/vjxw9jx51dl08gjq4h3_3h7r0000gn/T/ipykernel_18650/1084489221.py:18: DeprecationWarning: SampleSet.samples() will return an iterable not an iterator in the future
#   optimal_solution = next(response.samples())
